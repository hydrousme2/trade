# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
with open('./lists/country_names_a_z.pkl', 'rb') as f:
    country_names = pickle.load(f)
country_names = np.array(country_names)
country_names.shape
# Out:
# (180,)

# %%
df = pd.read_excel("./data/GDP per capita.xls", sheet_name="data")
df.index = df['Country Name'].values
df.drop(['Country Code', 'Country Name', '2022'], axis=1, inplace=True)
df.head()
# Out:
#                                      2000          2001          2002  \
# Aruba                        21023.157513  20913.299497  21377.095185
# Africa Eastern and Southern    707.015752    628.225242    626.580853
# Afghanistan                    181.000000    125.000000    183.532775
# Africa Western and Central     520.786584    529.584939    619.773282
# Angola                         556.884244    527.463202    872.657772
#
#                                      2003          2004          2005  \
# Aruba                        22050.830932  24104.646177  24975.673257
# Africa Eastern and Southern    812.973645    985.563259   1120.484333
# Afghanistan                    200.462567    221.657604    255.055120
# Africa Western and Central     697.905291    841.357961   1000.869581
# Angola                         982.805601   1254.695563   1900.724725
#
#                                      2006          2007          2008  \
# ...

# %%
df2 = pd.read_excel("./data/API_NY.GDP.MKTP.CD_DS2_en_excel_v2_5551619.xls", sheet_name="data")
df2.index = df2['Country Name'].values
df2.drop(['Country Name', 'Country Code', '2022'], axis=1, inplace=True)
df2.head()
# Out:
#                                      2000          2001          2002  \
# Aruba                        1.873184e+09  1.896648e+09  1.962011e+09
# Africa Eastern and Southern  2.839379e+11  2.588300e+11  2.648815e+11
# Afghanistan                           NaN           NaN  3.854235e+09
# Africa Western and Central   1.404103e+11  1.467798e+11  1.766058e+11
# Angola                       9.129595e+09  8.936064e+09  1.528559e+10
#
#                                      2003          2004          2005  \
# Aruba                        2.044134e+09  2.254749e+09  2.359777e+09
# Africa Eastern and Southern  3.526741e+11  4.388531e+11  5.122337e+11
# Afghanistan                  4.539501e+09  5.220824e+09  6.226199e+09
# Africa Western and Central   2.044709e+11  2.534719e+11  3.100942e+11
# Angola                       1.781270e+10  2.355205e+10  3.697092e+10
#
#                                      2006          2007          2008  \
# ...

# %%
with open("./lists/country_names_a_z.pkl", 'rb') as f:
    country_names = pickle.load(f)
with open('./lists/commodities.pkl', 'rb') as f:
    commodities = pickle.load(f)

# %%
dfs = pd.DataFrame(columns=[f"{t}_{j}" for t in range(2000, 2022) for j in commodities.keys()], index=country_names)
dfs
# Out:
#             2000_2 2000_5 2000_7 2000_8 2000_22 2000_27 2000_4 2000_11  \
# Afghanistan    NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# Albania        NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# Algeria        NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# Andorra        NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# Angola         NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# ...            ...    ...    ...    ...     ...     ...    ...     ...
# Viet Nam       NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# Yemen          NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# Zambia         NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# Zimbabwe       NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
# ASEAN          NaN    NaN    NaN    NaN     NaN     NaN    NaN     NaN
#
#             2000_28 2000_0  ... 2021_6 2021_1 2021_12 2021_21 2021_26 2021_24  \
# ...

# %%
data = pd.read_excel("./data/commodity_wise_data.xlsx", sheet_name=list(commodities.values()))
data = dict(zip(list(commodities.keys()), list(data.values())))
data.keys()
# Out:
# dict_keys([2, 5, 7, 8, 22, 27, 4, 11, 28, 0, 6, 1, 12, 21, 26, 24, 3, 9, 23, 25])
